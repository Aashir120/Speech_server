# %%
import io
import os

# %%
from google.cloud import speech
from google.cloud import language_v1

# %%
client = speech.SpeechClient.from_service_account_file('key.json')

# The name of the audio file to transcribe
file_name = "files/audio.wav"

# Loads the audio into memory
with io.open(file_name, 'rb') as audio_file:
    content = audio_file.read()
    audio = speech.RecognitionAudio(content=content)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.ENCODING_UNSPECIFIED,
    sample_rate_hertz=48000,
    language_code='en-US')

# Detects speech in the audio file
response = client.recognize(config=config, audio=audio)
print(response)
transcription = ''
for result in response.results:
    transcription += result.alternatives[0].transcript

# Saves the transcribed text to a .txt file in the same directory
file = open("transcription.txt", "w")
file.write(transcription)
file.close()
# Out:
# results {
#   alternatives {
#     transcript: "English Learners that features natural unedited conversations between native speakers about interesting topics or hot issues or current events today I\'m joined by my co-host Anna Diana hi Andrew and hello listeners now I got a question for you Andrew yes right off the bat I love it what\'s up there\'s a famous seasonal song that often gets played around the holidays I\'m one of the lyrics is it"
#     confidence: 0.9480116367340088
#   }
#   result_end_time {
#     seconds: 29
#     nanos: 40000000
#   }
#   language_code: "en-us"
# }
# total_billed_time {
#   seconds: 30
# }
# request_id: 3698269767929242667

# %%
import io
import os

# Imports the Google Cloud client library
from google.cloud import speech

# Instantiates a client
client = speech.SpeechClient.from_service_account_file('key.json')

# The name of the audio file to transcribe
file_name = "files/audio2.wav"

# Loads the audio into memory
with io.open(file_name, 'rb') as audio_file:
    content = audio_file.read()
    audio = speech.RecognitionAudio(content=content)
    
diarization_config = speech.SpeakerDiarizationConfig(
    enable_speaker_diarization=True,
    min_speaker_count=2,
    max_speaker_count=10,
)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.ENCODING_UNSPECIFIED,
    sample_rate_hertz=48000,
    language_code='en-US',
    diarization_config=diarization_config,
)

# Detects speech in the audio file and performs speaker diarization
print("Waiting for operation to complete...")
response = client.recognize(config=config, audio=audio)

# Initialize speaker variables

speaker_id = 0
speaker_start = 0.0
dialogue = ""

for result in response.results:
    for word in result.alternatives[0].words:
        if word.speaker_tag != speaker_id:
            speaker_id = word.speaker_tag
            speaker_start = word.start_time.seconds
            speaker_start += word.start_time.seconds / 1000000000.0
            dialogue += "\n Speaker {}: \n".format(speaker_id)
        dialogue += word.word + " "
    speaker_end = result.alternatives[0].words[-1].end_time.seconds
    speaker_end += result.alternatives[0].words[-1].end_time.seconds / 1000000000.0
    dialogue += "\n ({:.2f}s - {:.2f}s)\n".format(speaker_start, speaker_end)

# Saves the transcribed and speaker diarized text to a .txt file in the same directory
file = open("diarization_result.txt", "w")
file.write(dialogue)
file.close()

print(response)
# Out:
# Waiting for operation to complete...
# results {
#   alternatives {
#     transcript: "English Learners that features natural unedited conversations between native speakers about interesting topics or hot issues or current events today I\'m joined by my co-host Anna Diana hi Andrew and hello listeners now I got a question for you Andrew yes right off the bat I love it what\'s up there\'s a famous seasonal song that often gets played around the holidays I\'m one of the lyrics is It\'s the Most Wonderful Time of the Year I was going to send that but then I decided not to you know what I\'m talking about right yeah it\'s the most wonderful time of the year a very famous song that sung are around this time of the year and and I think correct me if I\'m wrong but I think the song title is"
#     confidence: 0.9715204238891602
#     words {
#       start_time {
#       }
#       end_time {
#         nanos: 500000000
#       }
#       word: "English"
#     }
#     words {
#       start_time {
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 1
#       }
#       word: "Learners"
#     }
#     words {
#       start_time {
#         seconds: 1
#       }
#       end_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 2
#       }
#       word: "features"
#     }
#     words {
#       start_time {
#         seconds: 2
#       }
#       end_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       word: "natural"
#     }
#     words {
#       start_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       word: "unedited"
#     }
#     words {
#       start_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       word: "conversations"
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       word: "between"
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       word: "native"
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       word: "speakers"
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       word: "about"
#     }
#     words {
#       start_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       word: "interesting"
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       word: "topics"
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       word: "or"
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       word: "hot"
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 9
#       }
#       word: "issues"
#     }
#     words {
#       start_time {
#         seconds: 9
#       }
#       end_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       word: "or"
#     }
#     words {
#       start_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       word: "current"
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       word: "events"
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       word: "today"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       word: "joined"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 12
#       }
#       word: "by"
#     }
#     words {
#       start_time {
#         seconds: 12
#       }
#       end_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       word: "my"
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       word: "co-host"
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       word: "Anna"
#     }
#     words {
#       start_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       word: "Diana"
#     }
#     words {
#       start_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       word: "hi"
#     }
#     words {
#       start_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       word: "Andrew"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       word: "hello"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       word: "listeners"
#     }
#     words {
#       start_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       word: "now"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "got"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       word: "question"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       word: "for"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       word: "you"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       word: "Andrew"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       word: "yes"
#     }
#     words {
#       start_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       word: "right"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       word: "off"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       word: "bat"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       word: "love"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       word: "it"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       word: "what\'s"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       word: "up"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       word: "there\'s"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       word: "famous"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       word: "seasonal"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       word: "often"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       word: "gets"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       word: "played"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       word: "around"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 27
#       }
#       word: "holidays"
#     }
#     words {
#       start_time {
#         seconds: 27
#       }
#       end_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "one"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 28
#       }
#       word: "lyrics"
#     }
#     words {
#       start_time {
#         seconds: 28
#       }
#       end_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       word: "is"
#     }
#     words {
#       start_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 29
#       }
#       word: "It\'s"
#     }
#     words {
#       start_time {
#         seconds: 29
#       }
#       end_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       word: "Most"
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       word: "Wonderful"
#     }
#     words {
#       start_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#       }
#       word: "Time"
#     }
#     words {
#       start_time {
#         seconds: 31
#       }
#       end_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "Year"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       word: "was"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       word: "going"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       word: "to"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       word: "send"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       word: "but"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       word: "then"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       word: "decided"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 34
#       }
#       word: "not"
#     }
#     words {
#       start_time {
#         seconds: 34
#       }
#       end_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       word: "to"
#     }
#     words {
#       start_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       word: "you"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       word: "know"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       word: "what"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       word: "talking"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       word: "about"
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       word: "right"
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       word: "yeah"
#     }
#     words {
#       start_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#       }
#       word: "it\'s"
#     }
#     words {
#       start_time {
#         seconds: 38
#       }
#       end_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       word: "most"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       word: "wonderful"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       word: "time"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       word: "year"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       word: "very"
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       word: "famous"
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       word: "sung"
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       word: "are"
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       word: "around"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       word: "this"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       word: "time"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       word: "year"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       word: "think"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       word: "correct"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       word: "me"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       word: "if"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 47
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 47
#       }
#       end_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       word: "wrong"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       word: "but"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       word: "think"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 48
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 48
#       }
#       end_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       word: "title"
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 49
#         nanos: 200000000
#       }
#       word: "is"
#     }
#   }
#   result_end_time {
#     seconds: 49
#     nanos: 320000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     words {
#       start_time {
#       }
#       end_time {
#         nanos: 500000000
#       }
#       word: "English"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 1
#       }
#       word: "Learners"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 1
#       }
#       end_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       word: "that"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 2
#       }
#       word: "features"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 2
#       }
#       end_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       word: "natural"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       word: "unedited"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       word: "conversations"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       word: "between"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       word: "native"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       word: "speakers"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       word: "about"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       word: "interesting"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       word: "topics"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       word: "or"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       word: "hot"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 9
#       }
#       word: "issues"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 9
#       }
#       end_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       word: "or"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       word: "current"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       word: "events"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       word: "today"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       word: "I\'m"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       word: "joined"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 12
#       }
#       word: "by"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#       }
#       end_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       word: "my"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       word: "co-host"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       word: "Anna"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       word: "Diana"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       word: "hi"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       word: "Andrew"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       word: "and"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       word: "hello"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       word: "listeners"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       word: "now"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "got"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "a"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       word: "question"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       word: "for"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       word: "you"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       word: "Andrew"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       word: "yes"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       word: "right"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       word: "off"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       word: "bat"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       word: "love"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       word: "it"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       word: "what\'s"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       word: "up"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       word: "there\'s"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       word: "a"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       word: "famous"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       word: "seasonal"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       word: "song"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       word: "that"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       word: "often"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       word: "gets"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       word: "played"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       word: "around"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 27
#       }
#       word: "holidays"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#       }
#       end_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       word: "I\'m"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "one"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "of"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 28
#       }
#       word: "lyrics"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 28
#       }
#       end_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       word: "is"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 29
#       }
#       word: "It\'s"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#       }
#       end_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       word: "Most"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       word: "Wonderful"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#       }
#       word: "Time"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#       }
#       end_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       word: "of"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "Year"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       word: "was"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       word: "going"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       word: "to"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       word: "send"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       word: "that"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       word: "but"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       word: "then"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       word: "decided"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 34
#       }
#       word: "not"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 34
#       }
#       end_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       word: "to"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       word: "you"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       word: "know"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       word: "what"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       word: "I\'m"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       word: "talking"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       word: "about"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       word: "right"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       word: "yeah"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#       }
#       word: "it\'s"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#       }
#       end_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       word: "most"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       word: "wonderful"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       word: "time"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       word: "of"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       word: "year"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       word: "a"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       word: "very"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       word: "famous"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       word: "song"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       word: "that"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       word: "sung"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       word: "are"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       word: "around"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       word: "this"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       word: "time"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       word: "of"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       word: "year"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       word: "and"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       word: "and"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       word: "think"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       word: "correct"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       word: "me"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       word: "if"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 47
#       }
#       word: "I\'m"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#       }
#       end_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       word: "wrong"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       word: "but"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       word: "think"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 48
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#       }
#       end_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       word: "song"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       word: "title"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 49
#         nanos: 200000000
#       }
#       word: "is"
#       speaker_tag: 2
#     }
#   }
# }
# total_billed_time {
#   seconds: 50
# }
# request_id: 281072435117853861

# %%
import pickle

# Write the object to a file
def write_to_file(obj, file_name):
    file = open("diarization_result.txt", "wb")
    pickle.dump(response,file)

# Read the object from a file
def read_from_file(file_name):
    with open(file_name, 'rb') as f:
        return pickle.load(f)

# Example usage
my_dict = {'a': 1, 'b': 2, 'c': 3}
file_name = 'my_dict.txt'
write_to_file(response, "diarization_result.txt")

# Reading the dictionary back from the file
loaded_dict = read_from_file("diarization_result.txt")
print(loaded_dict) # outputs: {'a': 1, 'b': 2, 'c': 3}
# Out:
# results {
#   alternatives {
#     transcript: "English Learners that features natural unedited conversations between native speakers about interesting topics or hot issues or current events today I\'m joined by my co-host Anna Diana hi Andrew and hello listeners now I got a question for you Andrew yes right off the bat I love it what\'s up there\'s a famous seasonal song that often gets played around the holidays I\'m one of the lyrics is It\'s the Most Wonderful Time of the Year I was going to send that but then I decided not to you know what I\'m talking about right yeah it\'s the most wonderful time of the year a very famous song that sung are around this time of the year and and I think correct me if I\'m wrong but I think the song title is"
#     confidence: 0.9715204238891602
#     words {
#       start_time {
#       }
#       end_time {
#         nanos: 500000000
#       }
#       word: "English"
#     }
#     words {
#       start_time {
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 1
#       }
#       word: "Learners"
#     }
#     words {
#       start_time {
#         seconds: 1
#       }
#       end_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 2
#       }
#       word: "features"
#     }
#     words {
#       start_time {
#         seconds: 2
#       }
#       end_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       word: "natural"
#     }
#     words {
#       start_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       word: "unedited"
#     }
#     words {
#       start_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       word: "conversations"
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       word: "between"
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       word: "native"
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       word: "speakers"
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       word: "about"
#     }
#     words {
#       start_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       word: "interesting"
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       word: "topics"
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       word: "or"
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       word: "hot"
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 9
#       }
#       word: "issues"
#     }
#     words {
#       start_time {
#         seconds: 9
#       }
#       end_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       word: "or"
#     }
#     words {
#       start_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       word: "current"
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       word: "events"
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       word: "today"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       word: "joined"
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 12
#       }
#       word: "by"
#     }
#     words {
#       start_time {
#         seconds: 12
#       }
#       end_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       word: "my"
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       word: "co-host"
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       word: "Anna"
#     }
#     words {
#       start_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       word: "Diana"
#     }
#     words {
#       start_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       word: "hi"
#     }
#     words {
#       start_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       word: "Andrew"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       word: "hello"
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       word: "listeners"
#     }
#     words {
#       start_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       word: "now"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "got"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       word: "question"
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       word: "for"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       word: "you"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       word: "Andrew"
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       word: "yes"
#     }
#     words {
#       start_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       word: "right"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       word: "off"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       word: "bat"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       word: "love"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       word: "it"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       word: "what\'s"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       word: "up"
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       word: "there\'s"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       word: "famous"
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       word: "seasonal"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       word: "often"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       word: "gets"
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       word: "played"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       word: "around"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 27
#       }
#       word: "holidays"
#     }
#     words {
#       start_time {
#         seconds: 27
#       }
#       end_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "one"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 28
#       }
#       word: "lyrics"
#     }
#     words {
#       start_time {
#         seconds: 28
#       }
#       end_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       word: "is"
#     }
#     words {
#       start_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 29
#       }
#       word: "It\'s"
#     }
#     words {
#       start_time {
#         seconds: 29
#       }
#       end_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       word: "Most"
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       word: "Wonderful"
#     }
#     words {
#       start_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#       }
#       word: "Time"
#     }
#     words {
#       start_time {
#         seconds: 31
#       }
#       end_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "Year"
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       word: "was"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       word: "going"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       word: "to"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       word: "send"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       word: "but"
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       word: "then"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       word: "decided"
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 34
#       }
#       word: "not"
#     }
#     words {
#       start_time {
#         seconds: 34
#       }
#       end_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       word: "to"
#     }
#     words {
#       start_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       word: "you"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       word: "know"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       word: "what"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       word: "talking"
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       word: "about"
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       word: "right"
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       word: "yeah"
#     }
#     words {
#       start_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#       }
#       word: "it\'s"
#     }
#     words {
#       start_time {
#         seconds: 38
#       }
#       end_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       word: "most"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       word: "wonderful"
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       word: "time"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       word: "year"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       word: "a"
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       word: "very"
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       word: "famous"
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       word: "that"
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       word: "sung"
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       word: "are"
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       word: "around"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       word: "this"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       word: "time"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       word: "of"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       word: "year"
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       word: "and"
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       word: "think"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       word: "correct"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       word: "me"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       word: "if"
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 47
#       }
#       word: "I\'m"
#     }
#     words {
#       start_time {
#         seconds: 47
#       }
#       end_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       word: "wrong"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       word: "but"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       word: "I"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       word: "think"
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 48
#       }
#       word: "the"
#     }
#     words {
#       start_time {
#         seconds: 48
#       }
#       end_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       word: "song"
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       word: "title"
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 49
#         nanos: 200000000
#       }
#       word: "is"
#     }
#   }
#   result_end_time {
#     seconds: 49
#     nanos: 320000000
#   }
#   language_code: "en-us"
# }
# results {
#   alternatives {
#     words {
#       start_time {
#       }
#       end_time {
#         nanos: 500000000
#       }
#       word: "English"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 1
#       }
#       word: "Learners"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 1
#       }
#       end_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       word: "that"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 1
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 2
#       }
#       word: "features"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 2
#       }
#       end_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       word: "natural"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 2
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       word: "unedited"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 3
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       word: "conversations"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       word: "between"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 4
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       word: "native"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       word: "speakers"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 5
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       word: "about"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 6
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       word: "interesting"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       word: "topics"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 7
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       word: "or"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       word: "hot"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 8
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 9
#       }
#       word: "issues"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 9
#       }
#       end_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       word: "or"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 9
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       word: "current"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       word: "events"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 10
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       word: "today"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       word: "I\'m"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       word: "joined"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 11
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 12
#       }
#       word: "by"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#       }
#       end_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       word: "my"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       word: "co-host"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 12
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       word: "Anna"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 13
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       word: "Diana"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 14
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       word: "hi"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 15
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       word: "Andrew"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       word: "and"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       word: "hello"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 16
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       word: "listeners"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 17
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       word: "now"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "got"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       word: "a"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       word: "question"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 18
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       word: "for"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       word: "you"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       word: "Andrew"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 19
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       word: "yes"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 20
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       word: "right"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       word: "off"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       word: "bat"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 21
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       word: "love"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       word: "it"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       word: "what\'s"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       word: "up"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 22
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       word: "there\'s"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       word: "a"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       word: "famous"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 24
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       word: "seasonal"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       word: "song"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       word: "that"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       word: "often"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       word: "gets"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 25
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       word: "played"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       word: "around"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 26
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 27
#       }
#       word: "holidays"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#       }
#       end_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       word: "I\'m"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "one"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       word: "of"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 27
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 28
#       }
#       word: "lyrics"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 28
#       }
#       end_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       word: "is"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 28
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 29
#       }
#       word: "It\'s"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#       }
#       end_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       word: "Most"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 29
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       word: "Wonderful"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 30
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#       }
#       word: "Time"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#       }
#       end_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       word: "of"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       word: "Year"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 31
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       word: "was"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       word: "going"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       word: "to"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       word: "send"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       word: "that"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       word: "but"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 32
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       word: "then"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       word: "I"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       word: "decided"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 33
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 34
#       }
#       word: "not"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 34
#       }
#       end_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       word: "to"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 34
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       word: "you"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       word: "know"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       word: "what"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       word: "I\'m"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       word: "talking"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 35
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       word: "about"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       word: "right"
#       speaker_tag: 1
#     }
#     words {
#       start_time {
#         seconds: 36
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       word: "yeah"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 37
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#       }
#       word: "it\'s"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#       }
#       end_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       word: "most"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       word: "wonderful"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 38
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       word: "time"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       word: "of"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       word: "year"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       word: "a"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 39
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       word: "very"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       word: "famous"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 40
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       word: "song"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       word: "that"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 41
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       word: "sung"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       word: "are"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 42
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       word: "around"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 200000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       word: "this"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 300000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       word: "time"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       word: "of"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       word: "year"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 43
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       word: "and"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 44
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       word: "and"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 600000000
#       }
#       end_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 45
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       word: "think"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       word: "correct"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 700000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       word: "me"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       word: "if"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 46
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 47
#       }
#       word: "I\'m"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#       }
#       end_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       word: "wrong"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 100000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       word: "but"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       word: "I"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 500000000
#       }
#       end_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       word: "think"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 47
#         nanos: 800000000
#       }
#       end_time {
#         seconds: 48
#       }
#       word: "the"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#       }
#       end_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       word: "song"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 400000000
#       }
#       end_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       word: "title"
#       speaker_tag: 2
#     }
#     words {
#       start_time {
#         seconds: 48
#         nanos: 900000000
#       }
#       end_time {
#         seconds: 49
#         nanos: 200000000
#       }
#       word: "is"
#       speaker_tag: 2
#     }
#   }
# }
# total_billed_time {
#   seconds: 50
# }
# request_id: 281072435117853861

# %%
import argparse
import io
import json
import os

from google.cloud import language_v1
import numpy
import six

def classify(text, verbose=True):
    """Classify the input text into categories."""

    language_client = language_v1.LanguageServiceClient.from_service_account_file('key.json')

    document = language_v1.Document(
        content=text, type_=language_v1.Document.Type.PLAIN_TEXT
    )
    response = language_client.classify_text(request={"document": document})
    categories = response.categories

    result = {}
    topics=""

    for category in categories:
        # Turn the categories into a dictionary of the form:
        # {category.name: category.confidence}, so that they can
        # be treated as a sparse vector.
        result[category.name] = category.confidence

    if verbose:
        for category in categories:
           
            
            topics+=category.name+" \n"
            topics+=str(category.confidence)
            print(topics)

    return result

text=""
for i in loaded_dict.results:
    for j in i.alternatives:
        text += j.transcript
        
classify(text)
# Out:
# /Jobs & Education/Education
# 0.9100000262260437
# /Jobs & Education/Education
# 0.9100000262260437/Reference/Language Resources/Foreign Language Resources
# 0.8100000023841858
# {'/Jobs & Education/Education': 0.9100000262260437,
#  '/Reference/Language Resources/Foreign Language Resources': 0.8100000023841858}

# %%
from google.cloud import speech_v1p1beta1 as speech

client = speech.SpeechClient.from_service_account_file('key.json')

speech_file = "files/audio2.wav"

with open(speech_file, "rb") as audio_file:
    content = audio_file.read()

audio = speech.RecognitionAudio(content=content)

diarization_config = speech.SpeakerDiarizationConfig(
    enable_speaker_diarization=True,
    min_speaker_count=2,
    max_speaker_count=10,
)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=48000,
    language_code="en-US",
    diarization_config=diarization_config,
)

print("Waiting for operation to complete...")
response = client.recognize(config=config, audio=audio)

# The transcript within each result is separate and sequential per result.
# However, the words list within an alternative includes all the words
# from all the results thus far. Thus, to get all the words with speaker
# tags, you only have to take the words list from the last result:
result = response.results[-1]

words_info = result.alternatives[0].words

# Printing out the output:
for word_info in words_info:
    print(
        "word: '{}', speaker_tag: {}".format(word_info.word, word_info.speaker_tag)
    )
# Out:
# Waiting for operation to complete...
# word: 'English', speaker_tag: 2
# word: 'Learners', speaker_tag: 2
# word: 'that', speaker_tag: 2
# word: 'features', speaker_tag: 2
# word: 'natural', speaker_tag: 2
# word: 'unedited', speaker_tag: 2
# word: 'conversations', speaker_tag: 2
# word: 'between', speaker_tag: 2
# word: 'native', speaker_tag: 2
# word: 'speakers', speaker_tag: 2
# word: 'about', speaker_tag: 2
# word: 'interesting', speaker_tag: 2
# word: 'topics', speaker_tag: 2
# word: 'or', speaker_tag: 2
# word: 'hot', speaker_tag: 2
# word: 'issues', speaker_tag: 2
# word: 'or', speaker_tag: 2
# word: 'current', speaker_tag: 2
# word: 'events', speaker_tag: 2
# word: 'today', speaker_tag: 2
# word: 'I'm', speaker_tag: 2
# word: 'joined', speaker_tag: 2
# word: 'by', speaker_tag: 2
# word: 'my', speaker_tag: 2
# word: 'co-host', speaker_tag: 2
# word: 'Anna', speaker_tag: 2
# word: 'Diana', speaker_tag: 3
# word: 'hi', speaker_tag: 3
# word: 'Andrew', speaker_tag: 1
# word: 'and', speaker_tag: 1
# word: 'hello', speaker_tag: 1
# word: 'listeners', speaker_tag: 1
# word: 'now', speaker_tag: 1
# word: 'I', speaker_tag: 1
# word: 'got', speaker_tag: 1
# word: 'a', speaker_tag: 1
# word: 'question', speaker_tag: 1
# word: 'for', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'Andrew', speaker_tag: 1
# word: 'yes', speaker_tag: 2
# word: 'right', speaker_tag: 2
# word: 'off', speaker_tag: 2
# word: 'the', speaker_tag: 2
# word: 'bat', speaker_tag: 2
# word: 'I', speaker_tag: 2
# word: 'love', speaker_tag: 2
# word: 'it', speaker_tag: 2
# word: 'what's', speaker_tag: 2
# word: 'up', speaker_tag: 2
# word: 'there's', speaker_tag: 1
# word: 'a', speaker_tag: 1
# word: 'famous', speaker_tag: 1
# word: 'seasonal', speaker_tag: 1
# word: 'song', speaker_tag: 1
# word: 'that', speaker_tag: 1
# word: 'often', speaker_tag: 1
# word: 'gets', speaker_tag: 1
# word: 'played', speaker_tag: 1
# word: 'around', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'holidays', speaker_tag: 1
# word: 'I'm', speaker_tag: 1
# word: 'one', speaker_tag: 1
# word: 'of', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'lyrics', speaker_tag: 1
# word: 'is', speaker_tag: 1
# word: 'It's', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'Most', speaker_tag: 1
# word: 'Wonderful', speaker_tag: 1
# word: 'Time', speaker_tag: 1
# word: 'of', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'Year', speaker_tag: 1
# word: 'I', speaker_tag: 1
# word: 'was', speaker_tag: 1
# word: 'going', speaker_tag: 1
# word: 'to', speaker_tag: 1
# word: 'send', speaker_tag: 1
# word: 'that', speaker_tag: 1
# word: 'but', speaker_tag: 1
# word: 'then', speaker_tag: 1
# word: 'I', speaker_tag: 1
# word: 'decided', speaker_tag: 1
# word: 'not', speaker_tag: 1
# word: 'to', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'know', speaker_tag: 1
# word: 'what', speaker_tag: 1
# word: 'I'm', speaker_tag: 1
# word: 'talking', speaker_tag: 1
# word: 'about', speaker_tag: 1
# word: 'right', speaker_tag: 1
# word: 'yeah', speaker_tag: 2
# word: 'it's', speaker_tag: 2
# word: 'the', speaker_tag: 2
# word: 'most', speaker_tag: 2
# word: 'wonderful', speaker_tag: 2
# word: 'time', speaker_tag: 2
# word: 'of', speaker_tag: 2
# word: 'the', speaker_tag: 2
# word: 'year', speaker_tag: 2
# word: 'a', speaker_tag: 2
# word: 'very', speaker_tag: 2
# word: 'famous', speaker_tag: 2
# word: 'song', speaker_tag: 2
# word: 'that', speaker_tag: 2
# word: 'sung', speaker_tag: 2
# word: 'are', speaker_tag: 2
# word: 'around', speaker_tag: 2
# word: 'this', speaker_tag: 2
# word: 'time', speaker_tag: 2
# word: 'of', speaker_tag: 2
# word: 'the', speaker_tag: 2
# word: 'year', speaker_tag: 2
# word: 'and', speaker_tag: 2
# word: 'and', speaker_tag: 2
# word: 'I', speaker_tag: 2
# word: 'think', speaker_tag: 2
# word: 'correct', speaker_tag: 2
# word: 'me', speaker_tag: 2
# word: 'if', speaker_tag: 2
# word: 'I'm', speaker_tag: 2
# word: 'wrong', speaker_tag: 2
# word: 'but', speaker_tag: 2
# word: 'I', speaker_tag: 2
# word: 'think', speaker_tag: 2
# word: 'the', speaker_tag: 2
# word: 'song', speaker_tag: 2
# word: 'title', speaker_tag: 2
# word: 'is', speaker_tag: 2

# %%
from pydub import AudioSegment
import webrtcvad
import numpy as np

# Load the audio file
sound = AudioSegment.from_file("path/to/audio.wav", format="wav")

# Convert the audio to a raw PCM format
raw_audio = sound.raw_data

# Set the aggressiveness mode for the VAD (0-3)
aggressiveness = 2

# Create a VAD object
vad = webrtcvad.Vad(aggressiveness)

# Define the frame size and stride in milliseconds
frame_size = 30
frame_stride = 10

# Calculate the number of frames
frame_bytes = int(round(frame_size * sound.frame_rate * sound.channels * sound.sample_width / 1000))
frame_stride_bytes = int(round(frame_stride * sound.frame_rate * sound.channels * sound.sample_width / 1000))

# Split the audio into overlapping frames
frames = [raw_audio[i:i + frame_bytes] for i in range(0, len(raw_audio), frame_stride_bytes)]

# Initialize an array to store the speaker labels
labels = np.zeros(len(frames))

# Initialize the current speaker label
current_label = 0

# Iterate over each frame
for i, frame in enumerate(frames):
    # Use the VAD to check if the frame contains speech
    is_speech = vad.is_speech(frame, sound.frame_rate)

    # If the frame contains speech, assign it the current speaker label
    if is_speech:
        labels[i] = current_label

        # Increment the current speaker label
        current_label += 1

# Print the speaker labels
print(labels)

# %%
from google.cloud import speech_v1p1beta1 as speech

client = speech.SpeechClient.from_service_account_file('key.json')

speech_file = "files/dailylife013.mp3"

with open(speech_file, "rb") as audio_file:
    content = audio_file.read()

audio = speech.RecognitionAudio(content=content)

diarization_config = speech.SpeakerDiarizationConfig(
    enable_speaker_diarization=True,
    min_speaker_count=2,
    max_speaker_count=10,
)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.ENCODING_UNSPECIFIED ,
    sample_rate_hertz=8000,
    language_code="en-US",
    diarization_config=diarization_config,
)

print("Waiting for operation to complete...")
response = client.recognize(config=config, audio=audio)

# The transcript within each result is separate and sequential per result.
# However, the words list within an alternative includes all the words
# from all the results thus far. Thus, to get all the words with speaker
# tags, you only have to take the words list from the last result:
result = response.results[-1]

words_info = result.alternatives[0].words

current_speaker = None
with open("output.txt", "w") as file:
    for word_info in words_info:
        if current_speaker != word_info.speaker_tag:
            current_speaker = word_info.speaker_tag
            line = "Speaker {}: ".format(current_speaker)
        else:
            line = " " * len("Speaker {}: ".format(current_speaker))
        line += "{} ({} - {})\n".format(word_info.word, word_info.start_time.seconds, word_info.end_time.seconds)
        file.write(line)

print('done')
# Out:
# Waiting for operation to complete...
# done

# %%
text=""
for i in response.results:
    for j in i.alternatives:
        text+= j.transcript
        
print(text)
# Out:
# we need to save money why do we need to save money because we need to buy a house but I house is too expensive that's why we need to save money how much do we need to save we need to save enough for a down payment how much is that that's about $30,000 $30,000 that will take forever not if we save every penny okay here's 7 pennies
